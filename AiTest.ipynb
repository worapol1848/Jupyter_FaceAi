# %%
1+1
# Out:
# 2

# %%
2-2
# Out:
# 0

# %%
3-3
# Out:
# 0

# %%
3*3
# Out:
# 9

# %%
2/1
# Out:
# 2.0

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 =! 3
# Out:
#   Cell In[9], line 1
#     1 =get_ipython().getoutput(' 3')
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1!= 3
# Out:
# True
